# %% [markdown]
# # Wordle CLI
#
# The notebook prototype has been refactored into the Python package in this workspace.
#
# Run the assistant from a terminal with:
#
# `./.venv/bin/python -m wordle_solver`
